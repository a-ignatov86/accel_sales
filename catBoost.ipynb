# %% [markdown]
# # imports

# %%
import datetime as dt
from datetime import date
import os
from dotenv import load_dotenv

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# import mysql.connector as myPy
# from mysql.connector import Error
# import statsmodels.api as sm
# from statsmodels.tsa.seasonal import seasonal_decompose #для статистических моделей (ARIMA, экспоненциальное сглаживание)
from prophet import Prophet # для моделей машинного обучения
from sklearn.metrics import root_mean_squared_error as rmse,  r2_score, mean_absolute_percentage_error
import catboost
from catboost import CatBoostRegressor

# %% [markdown]
# # load data
#
# https://habr.com/ru/companies/mvideo/articles/771820/
#
# https://practicum.yandex.ru/blog/algoritm-gradientnogo-bustinga-catboost/

# %%
df_month_val = pd.read_csv('data/Month_Value_1.csv')
df_month_val
# Out:
#         Period       Revenue  Sales_quantity  Average_cost  \
# 0   01.01.2015  1.601007e+07         12729.0   1257.763541
# 1   01.02.2015  1.580759e+07         11636.0   1358.507000
# 2   01.03.2015  2.204715e+07         15922.0   1384.697024
# 3   01.04.2015  1.881458e+07         15227.0   1235.606705
# 4   01.05.2015  1.402148e+07          8620.0   1626.621765
# ..         ...           ...             ...           ...
# 91  01.08.2022           NaN             NaN           NaN
# 92  01.09.2022           NaN             NaN           NaN
# 93  01.10.2022           NaN             NaN           NaN
# 94  01.11.2022           NaN             NaN           NaN
# 95  01.12.2022           NaN             NaN           NaN
#
#     The_average_annual_payroll_of_the_region
# 0                                 30024676.0
# 1                                 30024676.0
# 2                                 30024676.0
# 3                                 30024676.0
# ...

# %%
dataset = np.array([[1, 4, 5, 6], [4, 5, 6, 7], [30, 40, 50, 60], [20, 15, 85, 60]])
train_labels = [1.2, 3.4, 9.5, 24.5]
model_simple = CatBoostRegressor(learning_rate=0.1, depth=3, loss_function='RMSE')
fit_model_simple = model_simple.fit(dataset, train_labels)

# print(fit_model_simple.get_params())

twenty_six = fit_model_simple.predict([22, 16, 87, 67])
twenty_six 
fit_model_simple.get_feature_importance(prettified=True)
# Out:
# 0:	learn: 8.8739868	total: 375us	remaining: 375ms
# 1:	learn: 8.6103948	total: 829us	remaining: 414ms
# 2:	learn: 8.3862529	total: 1.26ms	remaining: 421ms
# 3:	learn: 8.1765966	total: 1.63ms	remaining: 406ms
# 4:	learn: 7.9698872	total: 2.11ms	remaining: 420ms
# 5:	learn: 7.7364312	total: 2.27ms	remaining: 375ms
# 6:	learn: 7.5430204	total: 2.68ms	remaining: 381ms
# 7:	learn: 7.3229140	total: 2.88ms	remaining: 357ms
# 8:	learn: 7.1456490	total: 3.02ms	remaining: 333ms
# 9:	learn: 6.9782954	total: 3.15ms	remaining: 312ms
# 10:	learn: 6.7788290	total: 3.26ms	remaining: 293ms
# 11:	learn: 6.6483267	total: 3.45ms	remaining: 284ms
# 12:	learn: 6.4579159	total: 3.61ms	remaining: 274ms
# 13:	learn: 6.3377957	total: 3.74ms	remaining: 264ms
# 14:	learn: 6.1793508	total: 3.91ms	remaining: 257ms
# 15:	learn: 6.0248670	total: 4.06ms	remaining: 250ms
# 16:	learn: 5.8706599	total: 4.23ms	remaining: 244ms
# 17:	learn: 5.7034399	total: 4.4ms	remaining: 240ms
# ...
